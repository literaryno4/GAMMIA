# %%
import os.path as osp
import argparse
import numpy as np
import torch
import torch.nn.functional as F
from torch_geometric.datasets import Planetoid
import torch_geometric.transforms as T
from torch_geometric.nn import SAGEConv, GCNConv  # noqa

from models import GAT, GCN, GraphSage, get_opts
from GnnAttack import GnnAttack
from utils import process_mask

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

dataset_names = ['Cora', 'CiteSeer', 'PubMed']
model_names = ['GCN', 'GraphSage', 'GAT']
path='./data'
log_dir='gammia_mm_diff_target_log.txt'

# %%
def train(model, optimizer, data):
    model.train()
    optimizer.zero_grad()
    F.nll_loss(model(data.x, data.edge_index, data.edge_attr)[data.train_mask], data.y[data.train_mask]).backward()
    optimizer.step()
    
    return model

@torch.no_grad()
def test(model, data):
    model.eval()
    logits, accs = model(data.x, data.edge_index, data.edge_attr), []
    for _, mask in data('train_mask', 'val_mask', 'test_mask'):
        pred = logits[mask].max(1)[1]
        acc = pred.eq(data.y[mask]).sum().item() / mask.sum().item()
        accs.append(acc)
    return accs

def train_target(model, optimizer, data):
    best_model = None
    best_val_acc = test_acc = 0
    for epoch in range(1, 201):
        model = train(model, optimizer, data)
        train_acc, val_acc, tmp_test_acc = test(model, data)
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            test_acc = tmp_test_acc
            best_model = model
        log = 'Epoch: {:03d}, Train: {:.4f}, Val: {:.4f}, Test: {:.4f}'
    print(log.format(epoch, train_acc, best_val_acc, test_acc))
    return best_model

def train_shadow(model_shadow, optimizer, data):
    best_model_shadow = None
    best_val_acc = test_acc = 0
    for epoch in range(1, 201):
        model_shadow = train(model_shadow, optimizer, data)
        train_acc, val_acc, tmp_test_acc = test(model_shadow, data)
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            test_acc = tmp_test_acc
            best_model_shadow = model_shadow
        log = 'Epoch: {:03d}, Train: {:.4f}, Val: {:.4f}, Test: {:.4f}'
    print(log.format(epoch, train_acc, best_val_acc, test_acc))
    return best_model_shadow

def attack_nodes_list(models, data):
    attack_in_list = []
    attack_out_list = []
    for i in range(dataset.num_classes):
        atk_in = []
        atk_out = []
        for model in models:
            model.eval()
            logits = model(data.x, data.edge_index, data.edge_attr).detach().cpu().numpy()
            for l in range(len(logits)):
                if data.y[l] == i and data.train_mask[l]:
                    atk_in.append(logits[l])
                if data.y[l] == i and data.test_mask[l]:
                    atk_out.append(logits[l])
        attack_in_list.append(atk_in)
        attack_out_list.append(atk_out)
    
    return attack_in_list, attack_out_list

def attack(attack_in_train_list, attack_out_train_list, attack_in_list, attack_out_list, dataset, verbose=2):
    num_features = len(attack_in_train_list[0][0])
    num_classes = 2
    best_test_acc_list = []
    data = dataset[0].to(device)
    for i in range(dataset.num_classes):
        model = GraphSage(num_features, num_classes).to(device)
        optimizer = get_opts(model, 'GraphSage')
        gam = GnnAttack(data, attack_in_train_list[i], attack_out_train_list[i], attack_in_list[i], attack_out_list[i])
        best_test_acc_list.append(gam.attack(model, optimizer, device=device, epoches=1000, verbose=verbose))
    for i in range(len(best_test_acc_list)):
        print("class {}: {}".format(i, best_test_acc_list[i]))
        
    return best_test_acc_list

def write_log(best_test_acc_list, dataset_name, model_name, model_name_shadow):
    with open(log_dir, 'a') as f:
        f.write('{:.2f}/{:.2f}    '.format(np.mean(best_test_acc_list) * 100, np.max(best_test_acc_list) * 100))

def format_model_name(model_name):
    if model_name == 'GCN':
        return 'GCN          '
    elif model_name == 'GraphSage':
        return 'GraphSage    '
    elif model_name == 'GAT':
        return 'GAT          '

# %%
log_title = '\n\n-------------------------------Cora-------------------  ----------------------CiteSeer--------------  --------------------PubMed-----------------\ntar.\\shad.      GCN         GraphSage         GAT            GCN         GraphSage        GAT            GCN          GraphSage        GAT  \n------------------------------------------------------  --------------------------------------------  -------------------------------------------'
with open(log_dir, 'a') as f:
    f.write(log_title)

# %%
for model_name in model_names:
    with open(log_dir, 'a') as f:
        f.write('\n{}'.format(format_model_name(model_name)))
    for dataset_name in dataset_names:
        dataset = Planetoid(path, dataset_name, transform=T.NormalizeFeatures())
        data = dataset[0]
        num_features = dataset.num_features
        num_classes = dataset.num_classes
    
        exec("model = {}(num_features, num_classes).to(device)".format(model_name))
        data = data.to(device)
        optimizer = get_opts(model, model_name)
        best_model = train_target(model, optimizer, data)
        attack_in_list, attack_out_list = attack_nodes_list([best_model], data)
        for model_name_shadow in model_names:
            dataset = Planetoid(path, dataset_name, transform=T.NormalizeFeatures())
            data = dataset[0]
            data = process_mask(data).to(device)
            print("dataset: {}, target_model: {}, shadow_model: {}".format(dataset_name, model_name, model_name_shadow))
            shadow_models = []
            for i in range(dataset.num_classes):
#             for i in range(50):
                exec("model_shadow = {}(num_features, num_classes).to(device)".format(model_name_shadow))
                optimizer = get_opts(model_shadow, model_name_shadow)
                shadow_models.append(train_shadow(model_shadow, optimizer, data))
            attack_in_train_list, attack_out_train_list = attack_nodes_list(shadow_models, data)
#             attack_in_list, attack_out_list = attack_nodes_list([best_model], data)
            best_test_acc_list = attack(attack_in_train_list, attack_out_train_list, attack_in_list, attack_out_list, dataset, verbose=2)
            write_log(best_test_acc_list, dataset_name, model_name, model_name_shadow)
# Out:
# Epoch: 200, Train: 1.0000, Val: 0.7860, Test: 0.8000
# dataset: Cora, target_model: GCN, shadow_model: GCN
# Epoch: 200, Train: 0.9929, Val: 0.8540, Test: 0.7850
# Epoch: 200, Train: 1.0000, Val: 0.8360, Test: 0.7910
# Epoch: 200, Train: 0.9929, Val: 0.8640, Test: 0.7880
# Epoch: 200, Train: 1.0000, Val: 0.8440, Test: 0.7850
# Epoch: 200, Train: 1.0000, Val: 0.8560, Test: 0.7950
# Epoch: 200, Train: 1.0000, Val: 0.8440, Test: 0.7670
# Epoch: 200, Train: 1.0000, Val: 0.8580, Test: 0.7660
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 5446
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.723
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 7096
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.721
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 5780
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.661
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 5340
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.736
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 5682
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.729
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 6242
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.726
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 7536
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.719
# ********************************************************************************
# class 0: 0.723
# class 1: 0.721
# class 2: 0.661
# class 3: 0.736
# class 4: 0.729
# class 5: 0.726
# class 6: 0.719
# dataset: Cora, target_model: GCN, shadow_model: GraphSage
# Epoch: 200, Train: 1.0000, Val: 0.8240, Test: 0.7500
# Epoch: 200, Train: 1.0000, Val: 0.8140, Test: 0.7360
# Epoch: 200, Train: 1.0000, Val: 0.8340, Test: 0.7580
# Epoch: 200, Train: 1.0000, Val: 0.8380, Test: 0.7690
# Epoch: 200, Train: 1.0000, Val: 0.8500, Test: 0.7560
# Epoch: 200, Train: 1.0000, Val: 0.8380, Test: 0.7590
# Epoch: 200, Train: 1.0000, Val: 0.8160, Test: 0.7470
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 5494
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.627
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 5262
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.72
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 5570
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.627
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 5968
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.578
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 5368
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.784
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 5272
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.711
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 5790
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.775
# ********************************************************************************
# class 0: 0.627
# class 1: 0.72
# class 2: 0.627
# class 3: 0.578
# class 4: 0.784
# class 5: 0.711
# class 6: 0.775
# dataset: Cora, target_model: GCN, shadow_model: GAT
# Epoch: 200, Train: 0.9929, Val: 0.8660, Test: 0.7890
# Epoch: 200, Train: 0.9929, Val: 0.8640, Test: 0.7900
# Epoch: 200, Train: 0.9929, Val: 0.8680, Test: 0.7930
# Epoch: 200, Train: 0.9929, Val: 0.8700, Test: 0.7950
# Epoch: 200, Train: 0.9857, Val: 0.8640, Test: 0.7870
# Epoch: 200, Train: 0.9857, Val: 0.8660, Test: 0.7860
# Epoch: 200, Train: 0.9929, Val: 0.8740, Test: 0.7950
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 5616
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.746
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 7338
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.713
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 5900
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.67
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 5418
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.792
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 5874
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.716
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 7010
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.687
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 8184
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.687
# ********************************************************************************
# class 0: 0.746
# class 1: 0.713
# class 2: 0.67
# class 3: 0.792
# class 4: 0.716
# class 5: 0.687
# class 6: 0.687
# Epoch: 200, Train: 0.9750, Val: 0.7160, Test: 0.7060
# dataset: CiteSeer, target_model: GCN, shadow_model: GCN
# Epoch: 200, Train: 0.9833, Val: 0.7300, Test: 0.7070
# Epoch: 200, Train: 0.9917, Val: 0.7300, Test: 0.6950
# Epoch: 200, Train: 0.9917, Val: 0.7220, Test: 0.6850
# Epoch: 200, Train: 0.9917, Val: 0.7220, Test: 0.6970
# Epoch: 200, Train: 0.9917, Val: 0.7320, Test: 0.7070
# Epoch: 200, Train: 0.9917, Val: 0.7220, Test: 0.6830
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 4490
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.7952047952047953
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 4558
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.8481518481518482
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 4634
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.8371628371628371
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 4492
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.8151848151848152
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 4486
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.7882117882117882
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 4836
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.7892107892107892
# ********************************************************************************
# class 0: 0.7952047952047953
# class 1: 0.8481518481518482
# class 2: 0.8371628371628371
# class 3: 0.8151848151848152
# class 4: 0.7882117882117882
# class 5: 0.7892107892107892
# dataset: CiteSeer, target_model: GCN, shadow_model: GraphSage
# Epoch: 200, Train: 1.0000, Val: 0.7180, Test: 0.6910
# Epoch: 200, Train: 1.0000, Val: 0.7080, Test: 0.6890
# Epoch: 200, Train: 1.0000, Val: 0.7180, Test: 0.6980
# Epoch: 200, Train: 1.0000, Val: 0.7160, Test: 0.6900
# Epoch: 200, Train: 1.0000, Val: 0.7080, Test: 0.6910
# Epoch: 200, Train: 1.0000, Val: 0.7220, Test: 0.7030
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 4616
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.8001998001998002
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 4982
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.7492507492507493
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 6500
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.6203796203796204
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 5258
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.7622377622377622
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 5204
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.6663336663336663
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 4562
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.7572427572427572
# ********************************************************************************
# class 0: 0.8001998001998002
# class 1: 0.7492507492507493
# class 2: 0.6203796203796204
# class 3: 0.7622377622377622
# class 4: 0.6663336663336663
# class 5: 0.7572427572427572
# dataset: CiteSeer, target_model: GCN, shadow_model: GAT
# Epoch: 200, Train: 0.9917, Val: 0.7340, Test: 0.7020
# Epoch: 200, Train: 0.9833, Val: 0.7420, Test: 0.7220
# Epoch: 200, Train: 0.9917, Val: 0.7400, Test: 0.7230
# Epoch: 200, Train: 0.9833, Val: 0.7380, Test: 0.7170
# Epoch: 200, Train: 0.9917, Val: 0.7340, Test: 0.7280
# Epoch: 200, Train: 0.9917, Val: 0.7340, Test: 0.7100
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 5120
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.8171828171828172
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 4620
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.8311688311688312
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 4802
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.8081918081918081
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 4892
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.9000999000999002
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 4650
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.8001998001998002
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 5400
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.7672327672327672
# ********************************************************************************
# class 0: 0.8171828171828172
# class 1: 0.8311688311688312
# class 2: 0.8081918081918081
# class 3: 0.9000999000999002
# class 4: 0.8001998001998002
# class 5: 0.7672327672327672
# Epoch: 200, Train: 1.0000, Val: 0.8080, Test: 0.7920
# dataset: PubMed, target_model: GCN, shadow_model: GCN
# Epoch: 200, Train: 1.0000, Val: 0.8060, Test: 0.8160
# Epoch: 200, Train: 1.0000, Val: 0.8140, Test: 0.8250
# Epoch: 200, Train: 1.0000, Val: 0.8060, Test: 0.8200
# Constructing graph dataset...
# preparing nodes...
# member: 9858, all: 19717
# member train: 30, train: 60
# Nodes: torch.Size([19717, 3])
# preparing edges...
# number of edges: 46702
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.7192807192807192
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 9858, all: 19717
# member train: 30, train: 60
# Nodes: torch.Size([19717, 3])
# preparing edges...
# number of edges: 46230
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.8001998001998002
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 9858, all: 19717
# member train: 30, train: 60
# Nodes: torch.Size([19717, 3])
# preparing edges...
# number of edges: 49962
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.7412587412587412
# ********************************************************************************
# class 0: 0.7192807192807192
# class 1: 0.8001998001998002
# class 2: 0.7412587412587412
# dataset: PubMed, target_model: GCN, shadow_model: GraphSage
# Epoch: 200, Train: 1.0000, Val: 0.7760, Test: 0.7850
# Epoch: 200, Train: 1.0000, Val: 0.7720, Test: 0.7850
# Epoch: 200, Train: 1.0000, Val: 0.7800, Test: 0.7960
# Constructing graph dataset...
# preparing nodes...
# member: 9858, all: 19717
# member train: 30, train: 60
# Nodes: torch.Size([19717, 3])
# preparing edges...
# number of edges: 45984
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.6923076923076923
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 9858, all: 19717
# member train: 30, train: 60
# Nodes: torch.Size([19717, 3])
# preparing edges...
# number of edges: 76160
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.5394605394605395
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 9858, all: 19717
# member train: 30, train: 60
# Nodes: torch.Size([19717, 3])
# preparing edges...
# number of edges: 45430
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.7472527472527473
# ********************************************************************************
# class 0: 0.6923076923076923
# class 1: 0.5394605394605395
# class 2: 0.7472527472527473
# dataset: PubMed, target_model: GCN, shadow_model: GAT
# Epoch: 200, Train: 1.0000, Val: 0.8060, Test: 0.8050
# Epoch: 200, Train: 1.0000, Val: 0.8100, Test: 0.8080
# Epoch: 200, Train: 1.0000, Val: 0.8220, Test: 0.8220
# Constructing graph dataset...
# preparing nodes...
# member: 9858, all: 19717
# member train: 30, train: 60
# Nodes: torch.Size([19717, 3])
# preparing edges...
# number of edges: 45444
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.7152847152847153
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 9858, all: 19717
# member train: 30, train: 60
# Nodes: torch.Size([19717, 3])
# preparing edges...
# number of edges: 44502
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.8221778221778222
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 9858, all: 19717
# member train: 30, train: 60
# Nodes: torch.Size([19717, 3])
# preparing edges...
# number of edges: 56828
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.7302697302697303
# ********************************************************************************
# class 0: 0.7152847152847153
# class 1: 0.8221778221778222
# class 2: 0.7302697302697303
# Epoch: 200, Train: 1.0000, Val: 0.7960, Test: 0.8030
# dataset: Cora, target_model: GraphSage, shadow_model: GCN
# Epoch: 200, Train: 1.0000, Val: 0.8500, Test: 0.7780
# Epoch: 200, Train: 1.0000, Val: 0.8480, Test: 0.7900
# Epoch: 200, Train: 1.0000, Val: 0.8500, Test: 0.7810
# Epoch: 200, Train: 1.0000, Val: 0.8540, Test: 0.7880
# Epoch: 200, Train: 1.0000, Val: 0.8620, Test: 0.7650
# Epoch: 200, Train: 1.0000, Val: 0.8440, Test: 0.7860
# Epoch: 200, Train: 0.9929, Val: 0.8440, Test: 0.7890
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 7356
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.714
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 7714
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.833
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 6562
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.714
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 6360
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.8
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 7746
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.687
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 6826
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.773
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 8568
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.583
# ********************************************************************************
# class 0: 0.714
# class 1: 0.833
# class 2: 0.714
# class 3: 0.8
# class 4: 0.687
# class 5: 0.773
# class 6: 0.583
# dataset: Cora, target_model: GraphSage, shadow_model: GraphSage
# Epoch: 200, Train: 1.0000, Val: 0.8340, Test: 0.7570
# Epoch: 200, Train: 1.0000, Val: 0.8380, Test: 0.7670
# Epoch: 200, Train: 1.0000, Val: 0.8380, Test: 0.7570
# Epoch: 200, Train: 1.0000, Val: 0.8360, Test: 0.7590
# Epoch: 200, Train: 1.0000, Val: 0.8360, Test: 0.7540
# Epoch: 200, Train: 1.0000, Val: 0.8440, Test: 0.7610
# Epoch: 200, Train: 1.0000, Val: 0.8300, Test: 0.7490
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 5954
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.844
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 6550
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.809
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 6448
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.779
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 5702
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.827
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 7162
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.846
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 6302
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.84
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 6812
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.758
# ********************************************************************************
# class 0: 0.844
# class 1: 0.809
# class 2: 0.779
# class 3: 0.827
# class 4: 0.846
# class 5: 0.84
# class 6: 0.758
# dataset: Cora, target_model: GraphSage, shadow_model: GAT
# Epoch: 200, Train: 0.9929, Val: 0.8540, Test: 0.7880
# Epoch: 200, Train: 0.9929, Val: 0.8620, Test: 0.7730
# Epoch: 200, Train: 0.9929, Val: 0.8700, Test: 0.8000
# Epoch: 200, Train: 0.9786, Val: 0.8600, Test: 0.7800
# Epoch: 200, Train: 0.9857, Val: 0.8620, Test: 0.7850
# Epoch: 200, Train: 0.9929, Val: 0.8620, Test: 0.7870
# Epoch: 200, Train: 0.9929, Val: 0.8680, Test: 0.7850
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 8700
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.772
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 8702
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.689
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 7156
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.68
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 6472
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.805
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 8362
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.625
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 7102
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.702
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 9376
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.578
# ********************************************************************************
# class 0: 0.772
# class 1: 0.689
# class 2: 0.68
# class 3: 0.805
# class 4: 0.625
# class 5: 0.702
# class 6: 0.578
# Epoch: 200, Train: 1.0000, Val: 0.7080, Test: 0.7020
# dataset: CiteSeer, target_model: GraphSage, shadow_model: GCN
# Epoch: 200, Train: 0.9917, Val: 0.7280, Test: 0.7040
# Epoch: 200, Train: 0.9917, Val: 0.7320, Test: 0.7030
# Epoch: 200, Train: 0.9833, Val: 0.7320, Test: 0.7120
# Epoch: 200, Train: 0.9917, Val: 0.7300, Test: 0.7120
# Epoch: 200, Train: 0.9917, Val: 0.7340, Test: 0.7080
# Epoch: 200, Train: 0.9917, Val: 0.7400, Test: 0.7110
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 5936
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.8371628371628371
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 5228
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.9180819180819181
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 5766
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.7842157842157842
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 4720
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.9530469530469531
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 6008
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.7602397602397603
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 6046
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.7522477522477522
# ********************************************************************************
# class 0: 0.8371628371628371
# class 1: 0.9180819180819181
# class 2: 0.7842157842157842
# class 3: 0.9530469530469531
# class 4: 0.7602397602397603
# class 5: 0.7522477522477522
# dataset: CiteSeer, target_model: GraphSage, shadow_model: GraphSage
# Epoch: 200, Train: 1.0000, Val: 0.7120, Test: 0.6830
# Epoch: 200, Train: 1.0000, Val: 0.7240, Test: 0.7000
# Epoch: 200, Train: 1.0000, Val: 0.7220, Test: 0.6880
# Epoch: 200, Train: 1.0000, Val: 0.7100, Test: 0.6830
# Epoch: 200, Train: 1.0000, Val: 0.7060, Test: 0.7050
# Epoch: 200, Train: 1.0000, Val: 0.7060, Test: 0.6800
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 5330
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.8931068931068931
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 4938
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.8901098901098901
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 5056
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.8451548451548452
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 4462
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.8911088911088911
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 4958
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.8621378621378621
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 5126
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.942057942057942
# ********************************************************************************
# class 0: 0.8931068931068931
# class 1: 0.8901098901098901
# class 2: 0.8451548451548452
# class 3: 0.8911088911088911
# class 4: 0.8621378621378621
# class 5: 0.942057942057942
# dataset: CiteSeer, target_model: GraphSage, shadow_model: GAT
# Epoch: 200, Train: 0.9833, Val: 0.7320, Test: 0.7200
# Epoch: 200, Train: 0.9833, Val: 0.7280, Test: 0.7120
# Epoch: 200, Train: 0.9833, Val: 0.7340, Test: 0.7210
# Epoch: 200, Train: 0.9833, Val: 0.7360, Test: 0.7270
# Epoch: 200, Train: 0.9917, Val: 0.7360, Test: 0.7210
# Epoch: 200, Train: 0.9917, Val: 0.7340, Test: 0.7400
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 7026
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.7992007992007992
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 5754
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.8211788211788211
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 6292
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.7942057942057942
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 4782
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.936063936063936
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 6364
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.7162837162837162
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 6324
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.7542457542457542
# ********************************************************************************
# class 0: 0.7992007992007992
# class 1: 0.8211788211788211
# class 2: 0.7942057942057942
# class 3: 0.936063936063936
# class 4: 0.7162837162837162
# class 5: 0.7542457542457542
# Epoch: 200, Train: 1.0000, Val: 0.8140, Test: 0.7760
# dataset: PubMed, target_model: GraphSage, shadow_model: GCN
# Epoch: 200, Train: 1.0000, Val: 0.8080, Test: 0.8190
# Epoch: 200, Train: 1.0000, Val: 0.8080, Test: 0.8200
# Epoch: 200, Train: 1.0000, Val: 0.8040, Test: 0.8200
# Constructing graph dataset...
# preparing nodes...
# member: 9858, all: 19717
# member train: 30, train: 60
# Nodes: torch.Size([19717, 3])
# preparing edges...
# number of edges: 65512
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.7422577422577422
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 9858, all: 19717
# member train: 30, train: 60
# Nodes: torch.Size([19717, 3])
# preparing edges...
# number of edges: 51876
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.7942057942057942
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 9858, all: 19717
# member train: 30, train: 60
# Nodes: torch.Size([19717, 3])
# preparing edges...
# number of edges: 62400
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.6583416583416584
# ********************************************************************************
# class 0: 0.7422577422577422
# class 1: 0.7942057942057942
# class 2: 0.6583416583416584
# dataset: PubMed, target_model: GraphSage, shadow_model: GraphSage
# Epoch: 200, Train: 1.0000, Val: 0.7780, Test: 0.7790
# Epoch: 200, Train: 1.0000, Val: 0.7780, Test: 0.7860
# Epoch: 200, Train: 1.0000, Val: 0.7740, Test: 0.7840
# Constructing graph dataset...
# preparing nodes...
# member: 9858, all: 19717
# member train: 30, train: 60
# Nodes: torch.Size([19717, 3])
# preparing edges...
# number of edges: 60600
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.7832167832167832
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 9858, all: 19717
# member train: 30, train: 60
# Nodes: torch.Size([19717, 3])
# preparing edges...
# number of edges: 46722
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.8901098901098901
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 9858, all: 19717
# member train: 30, train: 60
# Nodes: torch.Size([19717, 3])
# preparing edges...
# number of edges: 55542
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.7432567432567433
# ********************************************************************************
# class 0: 0.7832167832167832
# class 1: 0.8901098901098901
# class 2: 0.7432567432567433
# dataset: PubMed, target_model: GraphSage, shadow_model: GAT
# Epoch: 200, Train: 1.0000, Val: 0.8200, Test: 0.8190
# Epoch: 200, Train: 1.0000, Val: 0.8140, Test: 0.8220
# Epoch: 200, Train: 1.0000, Val: 0.8200, Test: 0.8210
# Constructing graph dataset...
# preparing nodes...
# member: 9858, all: 19717
# member train: 30, train: 60
# Nodes: torch.Size([19717, 3])
# preparing edges...
# number of edges: 63714
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.7332667332667333
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 9858, all: 19717
# member train: 30, train: 60
# Nodes: torch.Size([19717, 3])
# preparing edges...
# number of edges: 58044
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.8191808191808192
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 9858, all: 19717
# member train: 30, train: 60
# Nodes: torch.Size([19717, 3])
# preparing edges...
# number of edges: 59192
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.7632367632367633
# ********************************************************************************
# class 0: 0.7332667332667333
# class 1: 0.8191808191808192
# class 2: 0.7632367632367633
# Epoch: 200, Train: 0.9929, Val: 0.8260, Test: 0.8200
# dataset: Cora, target_model: GAT, shadow_model: GCN
# Epoch: 200, Train: 1.0000, Val: 0.8480, Test: 0.7840
# Epoch: 200, Train: 1.0000, Val: 0.8400, Test: 0.7820
# Epoch: 200, Train: 0.9929, Val: 0.8440, Test: 0.7790
# Epoch: 200, Train: 1.0000, Val: 0.8460, Test: 0.7830
# Epoch: 200, Train: 1.0000, Val: 0.8460, Test: 0.7880
# Epoch: 200, Train: 1.0000, Val: 0.8520, Test: 0.7660
# Epoch: 200, Train: 1.0000, Val: 0.8540, Test: 0.7900
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 5730
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.626
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 6386
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.686
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 5228
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.615
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 6856
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.63
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 5472
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.722
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# ...
# Epoch: 200, Train: 0.9929, Val: 0.8680, Test: 0.7980
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 5288
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.648
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 6884
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.681
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 5602
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.672
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 6268
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.66
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 5634
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.695
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 5970
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.626
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1354, all: 2708
# member train: 70, train: 140
# Nodes: torch.Size([2708, 7])
# preparing edges...
# number of edges: 7508
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.712
# ********************************************************************************
# class 0: 0.648
# class 1: 0.681
# class 2: 0.672
# class 3: 0.66
# class 4: 0.695
# class 5: 0.626
# class 6: 0.712
# Epoch: 200, Train: 0.9833, Val: 0.7340, Test: 0.7080
# dataset: CiteSeer, target_model: GAT, shadow_model: GCN
# Epoch: 200, Train: 0.9917, Val: 0.7300, Test: 0.7200
# Epoch: 200, Train: 0.9917, Val: 0.7300, Test: 0.6980
# Epoch: 200, Train: 0.9917, Val: 0.7400, Test: 0.7150
# Epoch: 200, Train: 0.9917, Val: 0.7360, Test: 0.6990
# Epoch: 200, Train: 0.9917, Val: 0.7380, Test: 0.6990
# Epoch: 200, Train: 0.9917, Val: 0.7200, Test: 0.7010
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 4364
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.8291708291708292
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 5028
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.7412587412587412
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 4562
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.7232767232767233
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 6290
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.6573426573426573
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 4542
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.8481518481518482
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 4570
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.7912087912087912
# ********************************************************************************
# class 0: 0.8291708291708292
# class 1: 0.7412587412587412
# class 2: 0.7232767232767233
# class 3: 0.6573426573426573
# class 4: 0.8481518481518482
# class 5: 0.7912087912087912
# dataset: CiteSeer, target_model: GAT, shadow_model: GraphSage
# Epoch: 200, Train: 1.0000, Val: 0.7140, Test: 0.6940
# Epoch: 200, Train: 1.0000, Val: 0.7160, Test: 0.7090
# Epoch: 200, Train: 1.0000, Val: 0.7140, Test: 0.6960
# Epoch: 200, Train: 1.0000, Val: 0.7200, Test: 0.7010
# Epoch: 200, Train: 1.0000, Val: 0.7140, Test: 0.6870
# Epoch: 200, Train: 1.0000, Val: 0.7060, Test: 0.6620
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 4734
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.7892107892107892
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 6864
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.6023976023976024
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 7490
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.6183816183816184
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 6966
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.5984015984015985
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 7810
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.6603396603396603
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 6218
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.6653346653346653
# ********************************************************************************
# class 0: 0.7892107892107892
# class 1: 0.6023976023976024
# class 2: 0.6183816183816184
# class 3: 0.5984015984015985
# class 4: 0.6603396603396603
# class 5: 0.6653346653346653
# dataset: CiteSeer, target_model: GAT, shadow_model: GAT
# Epoch: 200, Train: 0.9833, Val: 0.7360, Test: 0.7140
# Epoch: 200, Train: 0.9917, Val: 0.7360, Test: 0.7110
# Epoch: 200, Train: 0.9917, Val: 0.7200, Test: 0.7060
# Epoch: 200, Train: 0.9833, Val: 0.7380, Test: 0.7200
# Epoch: 200, Train: 0.9917, Val: 0.7400, Test: 0.7240
# Epoch: 200, Train: 0.9833, Val: 0.7380, Test: 0.7170
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 5036
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.8521478521478522
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 4460
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.8201798201798202
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 4488
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.7422577422577422
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 4490
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.9140859140859141
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 4754
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.8191808191808192
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 1663, all: 3327
# member train: 60, train: 120
# Nodes: torch.Size([3327, 6])
# preparing edges...
# number of edges: 4822
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.8251748251748252
# ********************************************************************************
# class 0: 0.8521478521478522
# class 1: 0.8201798201798202
# class 2: 0.7422577422577422
# class 3: 0.9140859140859141
# class 4: 0.8191808191808192
# class 5: 0.8251748251748252
# Epoch: 200, Train: 1.0000, Val: 0.7960, Test: 0.7810
# dataset: PubMed, target_model: GAT, shadow_model: GCN
# Epoch: 200, Train: 1.0000, Val: 0.8080, Test: 0.8140
# Epoch: 200, Train: 1.0000, Val: 0.8060, Test: 0.8170
# Epoch: 200, Train: 1.0000, Val: 0.8080, Test: 0.8200
# Constructing graph dataset...
# preparing nodes...
# member: 9858, all: 19717
# member train: 30, train: 60
# Nodes: torch.Size([19717, 3])
# preparing edges...
# number of edges: 44780
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.6503496503496503
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 9858, all: 19717
# member train: 30, train: 60
# Nodes: torch.Size([19717, 3])
# preparing edges...
# number of edges: 51646
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.7242757242757243
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 9858, all: 19717
# member train: 30, train: 60
# Nodes: torch.Size([19717, 3])
# preparing edges...
# number of edges: 44524
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.7422577422577422
# ********************************************************************************
# class 0: 0.6503496503496503
# class 1: 0.7242757242757243
# class 2: 0.7422577422577422
# dataset: PubMed, target_model: GAT, shadow_model: GraphSage
# Epoch: 200, Train: 1.0000, Val: 0.7740, Test: 0.7890
# Epoch: 200, Train: 1.0000, Val: 0.7800, Test: 0.7950
# Epoch: 200, Train: 1.0000, Val: 0.7860, Test: 0.7990
# Constructing graph dataset...
# preparing nodes...
# member: 9858, all: 19717
# member train: 30, train: 60
# Nodes: torch.Size([19717, 3])
# preparing edges...
# number of edges: 51892
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.6223776223776224
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 9858, all: 19717
# member train: 30, train: 60
# Nodes: torch.Size([19717, 3])
# preparing edges...
# number of edges: 74846
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.5644355644355644
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 9858, all: 19717
# member train: 30, train: 60
# Nodes: torch.Size([19717, 3])
# preparing edges...
# number of edges: 68794
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.6573426573426573
# ********************************************************************************
# class 0: 0.6223776223776224
# class 1: 0.5644355644355644
# class 2: 0.6573426573426573
# dataset: PubMed, target_model: GAT, shadow_model: GAT
# Epoch: 200, Train: 1.0000, Val: 0.8200, Test: 0.8240
# Epoch: 200, Train: 1.0000, Val: 0.8220, Test: 0.8180
# Epoch: 200, Train: 1.0000, Val: 0.8200, Test: 0.8330
# Constructing graph dataset...
# preparing nodes...
# member: 9858, all: 19717
# member train: 30, train: 60
# Nodes: torch.Size([19717, 3])
# preparing edges...
# number of edges: 52898
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.6643356643356644
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 9858, all: 19717
# member train: 30, train: 60
# Nodes: torch.Size([19717, 3])
# preparing edges...
# number of edges: 46612
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.7062937062937062
# ********************************************************************************
# Constructing graph dataset...
# preparing nodes...
# member: 9858, all: 19717
# member train: 30, train: 60
# Nodes: torch.Size([19717, 3])
# preparing edges...
# number of edges: 44780
# graph dataset constructed!
# ********************************************************************************
# test_acc: 0.7702297702297702
# ********************************************************************************
# class 0: 0.6643356643356644
# class 1: 0.7062937062937062
# class 2: 0.7702297702297702
